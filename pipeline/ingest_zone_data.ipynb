# %%
! wget https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv
# Out:
# --2026-01-18 09:05:08--  https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 3.164.82.40, 3.164.82.112, 3.164.82.197, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|3.164.82.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12331 (12K) [text/csv]
# Saving to: ‘taxi_zone_lookup.csv’
#
# taxi_zone_lookup.cs 100%[===================>]  12.04K  --.-KB/s    in 0.01s
#
# 2026-01-18 09:05:09 (1.03 MB/s) - ‘taxi_zone_lookup.csv’ saved [12331/12331]

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
pg_user = 'root'
pg_pass = 'root'
pg_host = 'localhost'
pg_port = '5432'
pg_db = 'ny_taxi'

# %%
engine = create_engine(f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}')

# %%
df_zones = pd.read_csv('taxi_zone_lookup.csv')

# %%
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zones.to_sql(name = 'zones', con = engine, if_exists = 'replace')
# Out:
# 265
